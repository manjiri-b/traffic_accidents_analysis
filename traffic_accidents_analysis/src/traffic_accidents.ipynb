# %% [markdown]
# 1. Import NYC_Accidents_2020.csv as a DataFrame

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/raw/NYC_Accidents_2020.csv", header=3)

# %% [markdown]
# When the csv file is imported without any specifications, the column names are not being read correctly. The actual table starts at index 2. This problem arises because in the actual csv file, the table starts from the 3rd line. To fix this, I added the extra argument header = 3 (since thats when it actual table starts).

# %% [markdown]
# 2. display columns and row samples

# %%
#show only the names of the columns
#Columns 
print("Columns: ")
print(df.columns)
# Out:
# Columns:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
#show the first 5 rows
df.head(5)
# Out:
#   CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0    8/29/20   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1    8/29/20   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2    8/29/20   18:20:00       NaN       NaN  40.81650 -73.946556
# 3    8/29/20    0:00:00     BRONX   10459.0  40.82472 -73.892960
# 4    8/29/20   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                  NaN  ...                    Unspecified
# 1                  NaN  ...                    Unspecified
# ...

# %%
#show a random sampling of 5 rows
df.sample(5)
# Out:
#       CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 58445     2/5/20    0:00:00        NaN       NaN        NaN        NaN
# 24514     6/5/20   17:00:00  MANHATTAN   10027.0  40.817257  -73.95713
# 42246     3/9/20    2:20:00        NaN       NaN  40.811220  -73.90067
# 2554     8/20/20   21:50:00     QUEENS   11101.0  40.744560  -73.93076
# 65846    1/20/20   19:00:00     QUEENS   11413.0  40.670630  -73.75643
#
#                           LOCATION       ON STREET NAME  \
# 58445                          NaN  CROSS BAY BOULEVARD
# 24514  POINT (-73.95713 40.817257)                  NaN
# 42246   POINT (-73.90067 40.81122)  BRUCKNER EXPRESSWAY
# 2554    POINT (-73.93076 40.74456)            34 STREET
# 65846   POINT (-73.75643 40.67063)             141 ROAD
#
#            CROSS STREET NAME OFF STREET NAME  ...  \
# 58445          SHORE PARKWAY             NaN  ...
# 24514                    NaN   3250 BROADWAY  ...
# ...

# %%
#show the last 5 rows
df.tail(5)
# Out:
#       CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 74876     1/1/20   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877     1/1/20    8:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878     1/1/20   11:36:00      BRONX   10461.0  40.848553 -73.830055
# 74879     1/1/20    1:45:00  MANHATTAN   10017.0  40.753624 -73.969440
# 74880     1/1/20   18:00:00     QUEENS   11367.0  40.726875 -73.830960
#
#                            LOCATION  ON STREET NAME CROSS STREET NAME  \
# 74876    POINT (-73.89651 40.82681)             NaN               NaN
# 74877   POINT (-73.95921 40.582935)             NaN               NaN
# 74878  POINT (-73.830055 40.848553)             NaN               NaN
# 74879   POINT (-73.96944 40.753624)  EAST 48 STREET          2 AVENUE
# 74880   POINT (-73.83096 40.726875)             NaN               NaN
#
#              OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# ...

# %% [markdown]
# 3. Describe the rows and data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74881 entries, 0 to 74880
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     74881 non-null  object
#  1   CRASH TIME                     74881 non-null  object
#  2   BOROUGH                        49140 non-null  object
#  3   ZIP CODE                       49134 non-null  float64
#  4   LATITUDE                       68935 non-null  float64
#  5   LONGITUDE                      68935 non-null  float64
#  6   LOCATION                       68935 non-null  object
#  7   ON STREET NAME                 55444 non-null  object
#  8   CROSS STREET NAME              35681 non-null  object
#  9   OFF STREET NAME                19437 non-null  object
#  10  NUMBER OF PERSONS INJURED      74881 non-null  int64
#  11  NUMBER OF PERSONS KILLED       74881 non-null  int64
# ...

# %% [markdown]
# 1. Zip code (index 3): doesn't have any decimals as it is a discrete variable so float64 is inappropriate for it. A more appropriate data type would be int64.
# 2. Number of Persons Injured (index 10), Number of Persons Killed (index 11), Number of Pedestrians Injured (index 12), Number of Pedestrians Killed (index 13), Number of Cyclist Injured (index 14), Number of Cyclist Killed (index 15), Number of Motorist Injured (index 16), Number of Motorist Killed(index 17): are of type int64. Generally, int64 is used to support datas of large values. The number of people injured/killed tend to be of lower numbers, hence int16 or int32 would be more appropriate data types to save space.
#
# Other cleaning necessary:
# Changing column names so that they are easier to work with, deleting redundant columns such as LOCATION, dropping all the rows where in latitude = 0 and longitude = 0 as it usually suggests that missing values have just been replaced by 0s. Latitude and Longitude cleanup was done during subsetting.

# %% [markdown]
# 4. initial column (or row) clean-up

# %%
#remove at least two columns

#Evidence of why Location column should be removed.
print("Let's observe the first row:")
print(df['LATITUDE'][0], df['LONGITUDE'][0], df['LOCATION'][0])

#Removing this coz same information in longitude and latitude column
del df['LOCATION']

#SHOW CODE TO SHOW WHY U DELETE

#The column numbers of person injured and numbers of person killed incorporates number of pedestrians, cyclists, motorist
del df['NUMBER OF PEDESTRIANS INJURED']
del df['NUMBER OF PEDESTRIANS KILLED']
del df['NUMBER OF CYCLIST INJURED']
del df['NUMBER OF CYCLIST KILLED']
del df['NUMBER OF MOTORIST INJURED']
del df['NUMBER OF MOTORIST KILLED']

#SHOW CODE TO SHOW WHY U DELETE

#Transforming columns (NaN Values replaced by 0)
df["ZIP CODE"] = df["ZIP CODE"].fillna(0).apply(np.int64)

#RENAMING COLUMNS
df.rename(columns={"CRASH DATE": "crash_date", "CRASH TIME": "crash_time", "ZIP CODE": "zip_code", 
                   "ON STREET NAME": "street", "NUMBER OF PERSONS INJURED": "people_injured", 
                   "NUMBER OF PERSONS KILLED": "people_killed"}, inplace=True)

#reason: makes columns easier to refer to and work with as decreases chances of syntax error, for example by missing 
#the space between the words, when referring to these columns
# Out:
# Let's observe the first row:
# 40.8921 -73.83376 POINT (-73.83376 40.8921)

# %% [markdown]
# Columns deleted:
# 1. The location column is just the latitude and longitude in coordinate format (observe 1st row's values from print(df['LATITUDE'][0], df['LONGITUDE'][0], df['LOCATION'][0]) code above). This is a redundant information hence it is not needed.
# 2. Columns 12-17 (index) were also deleted as the information they provide is already incorporated in the information provided by the number of persons injured and number of persons killed columns. These deleted columns just add more detail which is not necessary for our analysis.
#
# Renaming columns: "CRASH DATE", "CRASH TIME", "ZIP CODE","ON STREET NAME", "NUMBER OF PERSONS INJURED", "NUMBER OF PERSONS KILLED" were renamed.
# Makes columns easier to refer to and hence work with as decreases chances of syntax error, for example by missing
# the space between the words when referring to these columns. It also makes them less lengthy such as the number of persons injured column renaming.

# %% [markdown]
# 5. Determine the top three streets(Use the ON STREET NAME column) that had the most accidents

# %%
street_counts = df["street"].dropna().value_counts()
street_counts.head(3)
# Out:
# BELT PARKWAY                  1241
# LONG ISLAND EXPRESSWAY         745
# BROOKLYN QUEENS EXPRESSWAY     738
# Name: street, dtype: int64

# %% [markdown]
# The ON STREET NAME column was renamed to street and extracted using the syntax dataframe[columnname]. This syntax extracts the column as a pandas series. The function .dropna() was used to drop the all the NaNs in the series. The function .value_counts() was used on the series to counts the number of times each street occurs. By default, this function sorts the values in descending order. Then, the .head(3) functon was used to display the top three streets when it comes to number of accidents.

# %% [markdown]
# 6. Shows the number of accidents that occurred at each borough

# %%
import matplotlib.pyplot as plt

borough_data = df['BOROUGH'].fillna('OTHER').replace("STATEN ISLAND", "OTHER").value_counts()
borough_data.plot.bar(rot=0)
plt.xlabel("Borough")
plt.ylabel("Number of Accidents")
plt.title("Number of Accidents by Borough")
plt.show()

# %% [markdown]
# The borough column was subsetted using df['BOROUGH']. Since everything besides Brooklyn, Queens, Bronx and Manhattan is considered "OTHER", .fillna("OTHER") was used to replace the NaNs/missing values with the string "OTHER." Another borough that is not in the previous 4 is Staten Island. .replace() was used to replace all values that. are currently "STATEN ISLAND" to "OTHER". Next, .value_counts() was used to get the frequency of each unique element in the borough column. Then, .plot.bar() was used to visualize the data as a bar chart.

# %% [markdown]
# 7. Calculate summary statistics for the number of persons injured in all NYC and for a couple of selected boroughs (you can choose the two boroughs)

# %%
#Whole NYC Summary Statistics
print("Whole NYC People Injured Summary Statstics")
print(df['people_injured'].describe())

subset_manhattan = df.loc[df['BOROUGH'] == 'MANHATTAN', 'people_injured']
subset_brooklyn = df.loc[df['BOROUGH'] == 'BROOKLYN', 'people_injured']

#Manhattan Summary
print()
print("Manhattan People Injured Summary Statstics")
print(subset_manhattan.describe())

#Brooklyn Summary
print()
print("Brooklyn People Injured Summary Statstics")
print(subset_brooklyn.describe())
# Out:
# Whole NYC People Injured Summary Statstics
# count    74881.000000
# mean         0.366555
# std          0.726178
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         15.000000
# Name: people_injured, dtype: float64
#
# Manhattan People Injured Summary Statstics
# count    7353.000000
# mean        0.292534
# std         0.584037
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         5.000000
# Name: people_injured, dtype: float64
#
# Brooklyn People Injured Summary Statstics
# count    16907.000000
# mean         0.356302
# std          0.708303
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         15.000000
# Name: people_injured, dtype: float64

# %% [markdown]
# COMPARISON OF RESULTS:
# Brooklyn has more observations, 16907 than Manhattan, 7353. The mean for people injured for Manhattan is lesser than that of Brooklyn. The standard deviation for Brooklyn is higher than the standard deviation for Manhattan which suggests that the Brooklyn data for number of people injured is more spread out that that for Manhattan. Both have the same minimums, 0. Brooklyn has the higher maximum off 15 compared to Manhattan's 5. 75% of Brooklyn's observations fall below 1 person injured and 75% of Manhattan's observations fall below 0 people injured. This suggests that in general in Manhattan less people get injured in accidents.
#
# DOCUMENTATION OF STEPS:
# Data for the two chosen boroughs, Manhattan and Brooklyn were subsetted separately using the .loc[] function. In the first argument it was specified that only observations to be kept were if df['BOROUGH'] == 'MANHATTAN'/'BROOKLYN' respectively, and the second argument specifies that only the 'people_injured' column should be kept as that is the column of interest.

# %% [markdown]
# 8. What are the distributions of accidents based on the geo location (latitude & longitude)?

# %%
#Subseting the data by borough (for magnitude) using loc (dropping the NaN values using .dropna())
#Removing all values where Latitude and Longitude = 0 (SUGGESTS the authors of the data have replaced)
subset_manhattan_ll = df.loc[((df['BOROUGH'] == 'MANHATTAN') & (df['LATITUDE'] != 0) & (df['LONGITUDE'] != 0)), ['LATITUDE','LONGITUDE']].dropna()
subset_brooklyn_ll = df.loc[((df['BOROUGH'] == 'BROOKLYN') & (df['LATITUDE'] != 0) & (df['LONGITUDE'] != 0)), ['LATITUDE','LONGITUDE']].dropna()
subset_queens_ll = df.loc[((df['BOROUGH'] == 'QUEENS') & (df['LATITUDE'] != 0) & (df['LONGITUDE'] != 0)), ['LATITUDE','LONGITUDE']].dropna()
subset_bronx_ll = df.loc[((df['BOROUGH'] == 'BRONX') & (df['LATITUDE'] != 0) & (df['LONGITUDE'] != 0)), ['LATITUDE','LONGITUDE']].dropna()
subset_statenisland_ll = df.loc[((df['BOROUGH'] == 'STATEN ISLAND') & (df['LATITUDE'] != 0) & (df['LONGITUDE'] != 0)), ['LATITUDE','LONGITUDE']].dropna()

#Plotting the scatter plots
plt.scatter(subset_manhattan_ll['LATITUDE'],subset_manhattan_ll['LONGITUDE'], c = 'red', label = "Manhattan")
plt.scatter(subset_brooklyn_ll['LATITUDE'],subset_brooklyn_ll['LONGITUDE'],  c = 'blue', label = "Brooklyn")
plt.scatter(subset_queens_ll['LATITUDE'],subset_queens_ll['LONGITUDE'], c = 'green', label = "Queens")
plt.scatter(subset_bronx_ll['LATITUDE'],subset_bronx_ll['LONGITUDE'], c = 'coral', label = "Bronx")
plt.scatter(subset_statenisland_ll['LATITUDE'],subset_statenisland_ll['LONGITUDE'], c = 'purple', label = "Staten Island")
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Geo Location Distribution of Accidents')
plt.legend()
plt.show()

# %% [markdown]
# The data for each borough was subsetted using .loc[] function. 3 conditions were specified in the function. 1. Only observations of the respective borough should be kept through df['BOROUGH'] == respective borough name. 2. The data in the latitude column cannot be 0 and 3. the data in the longitude column cannot be 0. These latter two conditions were specified for cleaning up the data (aforementioned reason in question 3. in other cleaning necessary section). After this the .scatter() function with latitude column as x and longitude column as y was used to plot the data points for each borough. Keyword 'c' was used to specify the colors of the data points and 'label' was used to specify the name of the borough being plotted, which was then shown through the plt.legend() function. X-axis title, Y-axis title and main title were specified using plt.xlabel(), plt.ylabel() and plt.title() respectively.

# %% [markdown]
# ## 9. shows the covariance between each pair of the columns ##

# %%
#Columns I think we should calculate the covariance for
print(df['zip_code'].cov(df['people_injured']))
print(df['zip_code'].cov(df['people_killed']))
print(df['people_killed'].cov(df['people_injured']))
# Out:
# -200.6827441745322
# -3.2471048515210987
# 5.753720442558132e-05
# 0.0006172020503301104

# %% [markdown]
# Columns chosen:
# - Zipcode and People Injured: wanted to see if there is a relationship between zipcode and number of people injured. Can be useful in answering if in certain areas people tend to have more accidents, hence more injuries.
# - Zipcode and People Killed:  wanted to see if there is a relationship between zipcode and number of people killed for the same reason as the previous bullet point
# - People Injured and People Killed: wanted to explore the relationship between people injured and people killed. They havee a covariance of 0.0006172 which is very near 0. Hence, it indicates there is no linear relationship between the two varibles. This makes sense as two events are disjoint. One can either be injured or killed.
#
# Documentation:
# - Column1.cov(column2) was used to find the covariance between columns.

# %% [markdown]
# 10. Which month did the most number of accidents occur?

# %%
#Format: mm/dd/yy 
crash_dates =  [int(x.split('/')[0]) for x in df['crash_date']]
crash_dates_series = pd.Series(crash_dates).value_counts(sort=False)

crash_dates_series.plot.bar(rot=0)
plt.xlabel("Month")
plt.ylabel("Number of Accidents")
plt.title("Accidents By Month")
plt.show()

# %% [markdown]
# Janurary (month 1) had the most number of accidents. The number of accidents decreased from Januray onwards until it hit a lull at the month of April (lowest number of accidents). After April the number of accidents started increasing again.
#
# Clean up data process:
# List comprehension was used to collect the months from the crash date column. A for loop was used to iterate over each row in the column (iterator variable name: 'x'). Since the date is in "mm/dd/yy" format, .split('/') was used to break the string down into a list ["mm","dd","yy"]. The month is now the first element (index 0) of the list so x.split('/')[0] was used to isolate it. Then since the month is a string to convert it into int, int was used around the entire expression.
